# %% [markdown]
# ### Learning objectives
# * Understand and implement natural language processing using nltk
# * Plot frequency distribution graph
# * Use [Networkx](https://networkx.github.io/) & [Gephi](https://gephi.org/) for visualization using million dollar dataset
#
# **To-do List**
# * Install [Git Bash](https://git-scm.com/)
# * Find a Bing API to retrieve list of links of articles with similar keywords
#
# **Dataset Used**
#  MDL: [Million Dollar List](https://mdphil.webtest.iu.edu/data/download/thankyou.html)
#
# **Practice for Regular Expression:**
# [RegexOne](https://regexone.com/)

# %% [markdown]
# #Frequency Distribution
#
# **Explain frequency dist**
#
# * Frequency distribution shows the number of times a word is used in a document
# * Given a document, each unique word is considered one token, and the frequency i.e. the number of occurance is calculted.
#
# **Objective of Frequency Distribution**
#
# * By looking at the highest occuring words, one can infer the context or the main topic of the whole document.
#
# **Drawbacks**
#
# * We will get highest frequency for the words is, the, a, am etc..: These words are not significant for the analysis of any document
# * Same words used in different formats: paint, painting, painted, paints all mean the same but change the form according to sentence. This will generate many tokens for the same word and won't produce accurate results.

# %% [markdown]
# ##1. Importing packages and dataset
#
# **Packages Used**
#
# [nltk](https://www.nltk.org/): Natural Language Toolkit provides various functions to be performed on the human language to modify it and use it further for machine understanding objectives

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from nltk.stem.porter import *

# %%
df_main = pd.read_csv("https://mdphil.webtest.iu.edu/doc/donations.csv", encoding='latin-1')
print(list(df_main))
# Out:
# ['ID', 'Donor Name', 'Donor Type', 'Donor Group', 'Donor City', 'Donor State', 'Donor Country', 'Donor Division', 'Donor Region', 'Donor Description', 'Recipient', 'Recipient Notes', 'Recipient Subsector', 'Recipient Subsector (Secondary)', 'Recipient Sub Group', 'Recipient City', 'Recipient State', 'Recipient Country', 'Recipient Continent', 'Recipient Division', 'Recipient Region', 'Dollars', 'Donation Subgroup', 'Gift Notes', 'Gift Purpose', 'Source of Donor Wealth', 'Disaster', 'Pledge', 'Payment Over Time', 'Challenge Grant', 'Estate', 'Source', 'Foundation Search', 'Date Reported', 'Quarter', 'Year', 'To Own Foundation', 'Associated Foundation', 'Recipient Link', 'Donor Tidbits', 'Donor Continent']
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (24,29,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from nltk.stem.porter import *

# %%
df_main = pd.read_csv("https://mdphil.webtest.iu.edu/doc/donations.csv", encoding='latin-1')
#print(list(df_main))
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (24,29,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ##2. Generating list of words
#
# **1. Tokenization**
# [nltk.tokenize for word_tokenizer](https://www.nltk.org/api/nltk.tokenize.html)
#
# * Tokenization in this context is implemented on word-level
# * Given a large string, i.e. a document, it breaks it down into chunks everytime it encounters a "space" in the string
# * E.g., "data management and research life cycle" --> "data" "management" "and" "research" "life" "cycle" - breaks string anytime there is a space. this is case sensitive.
#
# **Provide an example using sentence**
#
#
# **2. Stop Words Removal**
# [nltk.corpus for stop_words](https://www.geeksforgeeks.org/removing-stop-words-nltk-python/)
# * Removing insignificant words from a document
# * Basic stop words: is, a, the, an, I, we etc..
# * The list of stop words may be appended depending on the document given and the objective of the task
# * Can specify the language you want to use for stop words
#
# **3. Stemmer**
# [nltk.stem.porter](https://www.nltk.org/api/nltk.stem.html)
# * Chopping off few ending characters of the word to simplify the word
# * Painting, paints, painted, paint ---> all treated as Paint after stemmer is applied
#
#
# **String Functions Used**
#
# 1. [s.lower](https://www.tutorialspoint.com/python/string_lower.htm): To lowercase all the characters in a word
# 2. [s.isalpha](https://www.geeksforgeeks.org/python-string-isalpha-application/): Returns True if the input consists of all characters being alphabets, returns false if a number is encountered
# 3, [More Functions](https://www.w3schools.com/python/python_ref_string.asp)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
stemmer=PorterStemmer()

stop_words=stopwords.words('english')

recipient_token_list=[]
for entry in df_main["Recipient"]:
    if str(entry)!='nan':
        recipient_token_list+=[stemmer.stem(s) for s in word_tokenize(entry) if s.lower() not in stop_words and s.isalpha()]
        
        recipient_token_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
stemmer=PorterStemmer()

stop_words=stopwords.words('english')

recipient_token_list=[]
for entry in df_main["Recipient"]:
    if str(entry)!='nan':
        recipient_token_list+=[stemmer.stem(s) for s in word_tokenize(entry) if s.lower() not in stop_words and s.isalpha()]

recipient_token_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['hurrican',
#  'relief',
#  'effort',
#  'variou',
#  'relief',
#  'effort',
#  'american',
#  'red',
#  'cross',
#  'chapman',
#  'univers',
#  'univers',
#  'maryland',
#  'adelphi',
#  'colgat',
#  'univers',
#  'smithsonian',
#  'institut',
#  'american',
#  'red',
#  'cross',
#  'smithsonian',
#  'institut',
#  'nation',
#  'museum',
#  'african',
#  'american',
#  'histori',
#  'cultur',
#  'martin',
#  'luther',
#  'king',
#  'Jr',
#  'nation',
#  'memori',
#  'variou',
#  'relief',
#  'effort',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'cascad',
#  'health',
#  'solut',
#  'variou',
#  'relief',
#  'effort',
#  'variou',
#  'nonprofit',
#  'organ',
#  'african',
#  'medic',
#  'research',
#  'foundat',
#  'african',
#  'medic',
#  'research',
#  'foundat',
#  'univers',
#  'goucher',
#  'colleg',
#  'sunnyval',
#  'commun',
#  'servic',
#  'univers',
#  'central',
#  'florida',
#  'auburn',
#  'univers',
#  'medic',
#  'center',
#  'central',
#  'georgia',
#  'american',
#  'committe',
#  'weizmann',
#  'institut',
#  'scienc',
#  'weizmann',
#  'institut',
#  'scienc',
#  'baylor',
#  'colleg',
#  'medicin',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'children',
#  'hospit',
#  'philadelphia',
#  'scripp',
#  'research',
#  'institut',
#  'univers',
#  'florida',
#  'J',
#  'craig',
#  'venter',
#  'institut',
#  'fashion',
#  'institut',
#  'technolog',
#  'virginia',
#  'commonwealth',
#  'univers',
#  'dominican',
#  'univers',
#  'california',
#  'St',
#  'lawrenc',
#  'univers',
#  'dartmouth',
#  'colleg',
#  'northwest',
#  'missouri',
#  'state',
#  'univers',
#  'katrina',
#  'fund',
#  'dalla',
#  'center',
#  'perform',
#  'art',
#  'univers',
#  'cincinnati',
#  'univers',
#  'washington',
#  'katrina',
#  'fund',
#  'variou',
#  'relief',
#  'effort',
#  'florida',
#  'state',
#  'univers',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'homeaid',
#  'america',
#  'homeaid',
#  'america',
#  'american',
#  'red',
#  'cross',
#  'carrabassett',
#  'valley',
#  'academi',
#  'variou',
#  'nonprofit',
#  'organ',
#  'intern',
#  'feder',
#  'red',
#  'cross',
#  'red',
#  'crescent',
#  'societi',
#  'institut',
#  'system',
#  'biolog',
#  'american',
#  'red',
#  'cross',
#  'organ',
#  'unicef',
#  'colleg',
#  'charleston',
#  'cuni',
#  'virginia',
#  'museum',
#  'fine',
#  'art',
#  'signatur',
#  'theatr',
#  'compani',
#  'georg',
#  'eastman',
#  'hous',
#  'five',
#  'colleg',
#  'leadership',
#  'enterpris',
#  'divers',
#  'america',
#  'stanford',
#  'cambridg',
#  'brooklyn',
#  'museum',
#  'art',
#  'southern',
#  'educ',
#  'foundat',
#  'joyc',
#  'theatr',
#  'brooklyn',
#  'museum',
#  'art',
#  'xavier',
#  'univers',
#  'louisiana',
#  'univers',
#  'massachusett',
#  'american',
#  'red',
#  'cross',
#  'church',
#  'divin',
#  'school',
#  'pacif',
#  'ringl',
#  'colleg',
#  'art',
#  'design',
#  'massachusett',
#  'societi',
#  'prevent',
#  'cruelti',
#  'anim',
#  'stanford',
#  'univers',
#  'american',
#  'heart',
#  'associ',
#  'lo',
#  'angel',
#  'divis',
#  'univers',
#  'pennsylvania',
#  'curti',
#  'institut',
#  'music',
#  'lo',
#  'angel',
#  'counti',
#  'fire',
#  'depart',
#  'care',
#  'american',
#  'red',
#  'cross',
#  'citi',
#  'santa',
#  'monica',
#  'univers',
#  'texa',
#  'dalla',
#  'open',
#  'societi',
#  'institut',
#  'univers',
#  'texa',
#  'houston',
#  'concordia',
#  'univers',
#  'texa',
#  'kidspac',
#  'children',
#  'museum',
#  'doan',
#  'colleg',
#  'univers',
#  'texa',
#  'dalla',
#  'potsdam',
#  'state',
#  'univers',
#  'colleg',
#  'univers',
#  'florida',
#  'wesleyan',
#  'colleg',
#  'univers',
#  'pennsylvania',
#  'phillip',
#  'exet',
#  'academi',
#  'burr',
#  'burton',
#  'academi',
#  'rice',
#  'univers',
#  'california',
#  'state',
#  'univers',
#  'monterey',
#  'bay',
#  'john',
#  'brown',
#  'univers',
#  'edgewood',
#  'colleg',
#  'commun',
#  'christ',
#  'church',
#  'cono',
#  'christian',
#  'school',
#  'central',
#  'baptist',
#  'colleg',
#  'methuselah',
#  'foundat',
#  'berri',
#  'colleg',
#  'san',
#  'marino',
#  'public',
#  'librari',
#  'bennington',
#  'colleg',
#  'warner',
#  'southern',
#  'colleg',
#  'church',
#  'divin',
#  'school',
#  'pacif',
#  'archer',
#  'school',
#  'girl',
#  'winthrop',
#  'univers',
#  'oregon',
#  'health',
#  'scienc',
#  'univers',
#  'stetson',
#  'univers',
#  'silver',
#  'lake',
#  'colleg',
#  'St',
#  'anselm',
#  'colleg',
#  'boy',
#  'girl',
#  'club',
#  'greater',
#  'cincinnati',
#  'brenau',
#  'univers',
#  'brown',
#  'univers',
#  'jewish',
#  'theolog',
#  'seminari',
#  'america',
#  'yale',
#  'univers',
#  'univers',
#  'oregon',
#  'john',
#  'hopkin',
#  'univers',
#  'austen',
#  'rigg',
#  'center',
#  'beth',
#  'chaverim',
#  'reform',
#  'congreg',
#  'nation',
#  'automat',
#  'merchandis',
#  'associ',
#  'michigan',
#  'state',
#  'univers',
#  'univers',
#  'arkansa',
#  'univers',
#  'north',
#  'carolina',
#  'chapel',
#  'hill',
#  'cape',
#  'cod',
#  'health',
#  'care',
#  'foundat',
#  'shriner',
#  'hospit',
#  'children',
#  'brown',
#  'univers',
#  'emerson',
#  'colleg',
#  'univers',
#  'texa',
#  'austin',
#  'high',
#  'point',
#  'univers',
#  'univers',
#  'california',
#  'berkeley',
#  'univers',
#  'cincinnati',
#  'univers',
#  'richmond',
#  'western',
#  'michigan',
#  'christian',
#  'high',
#  'school',
#  'univers',
#  'south',
#  'dakota',
#  'hospic',
#  'southern',
#  'main',
#  'southeastern',
#  'colleg',
#  'indiana',
#  'univers',
#  'greensboro',
#  'colleg',
#  'california',
#  'state',
#  'univers',
#  'sacramento',
#  'chicago',
#  'public',
#  'school',
#  'St',
#  'bonaventur',
#  'univers',
#  'warner',
#  'southern',
#  'colleg',
#  'new',
#  'york',
#  'univers',
#  'thoma',
#  'jefferson',
#  'univers',
#  'feed',
#  'children',
#  'gay',
#  'lesbian',
#  'straight',
#  'educ',
#  'network',
#  'boy',
#  'girl',
#  'club',
#  'america',
#  'portland',
#  'art',
#  'museum',
#  'portland',
#  'art',
#  'museum',
#  'univers',
#  'utah',
#  'trust',
#  'public',
#  'land',
#  'georgia',
#  'skidmor',
#  'colleg',
#  'john',
#  'hopkin',
#  'univers',
#  'texa',
#  'univers',
#  'variou',
#  'research',
#  'organ',
#  'univers',
#  'health',
#  'system',
#  'eastern',
#  'carolina',
#  'children',
#  'hospit',
#  'hope',
#  'lodg',
#  'big',
#  'brother',
#  'big',
#  'sister',
#  'america',
#  'children',
#  'aid',
#  'societi',
#  'duke',
#  'univers',
#  'american',
#  'red',
#  'cross',
#  'univers',
#  'oklahoma',
#  'rochest',
#  'gener',
#  'hospit',
#  'unit',
#  'servic',
#  'organ',
#  'american',
#  'red',
#  'cross',
#  'univers',
#  'north',
#  'carolina',
#  'chapel',
#  'hill',
#  'clemson',
#  'univers',
#  'east',
#  'carolina',
#  'univers',
#  'variou',
#  'relief',
#  'effort',
#  'cystic',
#  'fibrosi',
#  'foundat',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'intern',
#  'feder',
#  'red',
#  'cross',
#  'red',
#  'crescent',
#  'societi',
#  'art',
#  'scienc',
#  'council',
#  'H',
#  'lee',
#  'moffitt',
#  'cancer',
#  'center',
#  'research',
#  'institut',
#  'variou',
#  'nonprofit',
#  'organ',
#  'accion',
#  'philadelphia',
#  'zoo',
#  'hispan',
#  'scholarship',
#  'fund',
#  'univers',
#  'california',
#  'merc',
#  'world',
#  'trade',
#  'center',
#  'memori',
#  'indiana',
#  'univers',
#  'jackson',
#  'commun',
#  'colleg',
#  'jewish',
#  'women',
#  'archiv',
#  'palo',
#  'alto',
#  'jewish',
#  'commun',
#  'center',
#  'mclaughlin',
#  'reserv',
#  'florida',
#  'atlant',
#  'univers',
#  'wonder',
#  'wildlif',
#  'museum',
#  'american',
#  'red',
#  'cross',
#  'variou',
#  'nonprofit',
#  'organ',
#  'variou',
#  'relief',
#  'effort',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'variou',
#  'relief',
#  'effort',
#  'dalla',
#  'center',
#  'perform',
#  'art',
#  'tidewat',
#  'commun',
#  'colleg',
#  'harrisburg',
#  'area',
#  'commun',
#  'colleg',
#  'colorado',
#  'school',
#  'mine',
#  'peninsula',
#  'commun',
#  'foundat',
#  'univers',
#  'new',
#  'england',
#  'husson',
#  'colleg',
#  'mari',
#  'baldwin',
#  'colleg',
#  'tulan',
#  'univers',
#  'elmwood',
#  'american',
#  'red',
#  'cross',
#  'univers',
#  'minnesota',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'junior',
#  'achiev',
#  'variou',
#  'relief',
#  'effort',
#  'commun',
#  'foundat',
#  'calhoun',
#  'counti',
#  'elli',
#  'hospit',
#  'foundat',
#  'project',
#  'sussex',
#  'counti',
#  'miller',
#  'children',
#  'hospit',
#  'oneworld',
#  'health',
#  'innov',
#  'vector',
#  'control',
#  'consortium',
#  'popul',
#  'refer',
#  'bureau',
#  'wing',
#  'luke',
#  'museum',
#  'asian',
#  'pacif',
#  'american',
#  'experi',
#  'famili',
#  'health',
#  'intern',
#  'boy',
#  'girl',
#  'club',
#  'king',
#  'counti',
#  'save',
#  'children',
#  'intern',
#  'council',
#  'aid',
#  'servic',
#  'organ',
#  'american',
#  'red',
#  'cross',
#  'nation',
#  'commiss',
#  'human',
#  'develop',
#  'variou',
#  'relief',
#  'effort',
#  'fulcrum',
#  'foundat',
#  'institut',
#  'one',
#  'world',
#  'health',
#  'evergreen',
#  'state',
#  'colleg',
#  'center',
#  'strateg',
#  'intern',
#  'studi',
#  'donald',
#  'danforth',
#  'plant',
#  'scienc',
#  'center',
#  'austin',
#  'public',
#  'school',
#  'washington',
#  'state',
#  'univers',
#  'london',
#  'school',
#  'hygien',
#  'tropic',
#  'medicin',
#  'transatlant',
#  'partner',
#  'aid',
#  'freedom',
#  'hunger',
#  'grand',
#  'challeng',
#  'global',
#  'health',
#  'lakesid',
#  'school',
#  'georgia',
#  'depart',
#  'educ',
#  'univers',
#  'system',
#  'georgia',
#  'onlin',
#  'comput',
#  'librari',
#  'center',
#  'mapleton',
#  'public',
#  'school',
#  'washington',
#  'state',
#  'offic',
#  'public',
#  'instruct',
#  'albert',
#  'B',
#  'sabin',
#  'vaccin',
#  'institut',
#  'antioch',
#  'univers',
#  'seattl',
#  'nation',
#  'governor',
#  'associ',
#  'aspen',
#  'institut',
#  'engenderhealth',
#  'institut',
#  'research',
#  'reform',
#  'educ',
#  'carter',
#  'center',
#  'john',
#  'hopkin',
#  'univers',
#  'institut',
#  'research',
#  'reform',
#  'educ',
#  'greatschool',
#  'discoveri',
#  'institut',
#  'washington',
#  'famili',
#  'fund',
#  'medicin',
#  'malaria',
#  'ventur',
#  'onlin',
#  'comput',
#  'librari',
#  'center',
#  'asian',
#  'counsel',
#  'referr',
#  'servic',
#  'architect',
#  'achiev',
#  'nation',
#  'coalit',
#  'commun',
#  'foundat',
#  'youth',
#  'atlanta',
#  'public',
#  'school',
#  'fraunhof',
#  'usa',
#  'center',
#  'molecular',
#  'biotechnolog',
#  'boy',
#  'girl',
#  'club',
#  'south',
#  'puget',
#  'sound',
#  'washington',
#  'educ',
#  'foundat',
#  'univers',
#  'maryland',
#  'baltimor',
#  'imperi',
#  'colleg',
#  'scienc',
#  'technolog',
#  'medicin',
#  'harvard',
#  'univers',
#  'eastern',
#  'virginia',
#  'medic',
#  'school',
#  'success',
#  'practic',
#  'network',
#  'world',
#  'health',
#  'organ',
#  'institut',
#  'system',
#  'biolog',
#  'comput',
#  'histori',
#  'museum',
#  'colleg',
#  'entranc',
#  'examin',
#  'board',
#  'program',
#  'appropri',
#  'technolog',
#  'health',
#  'shidhulai',
#  'swanirvar',
#  'sangstha',
#  'crater',
#  'high',
#  'school',
#  'institut',
#  'teach',
#  'unicef',
#  'global',
#  'allianc',
#  'vaccin',
#  'immunis',
#  'univers',
#  'washington',
#  'univers',
#  'washington',
#  'bio',
#  'ventur',
#  'global',
#  'health',
#  'univers',
#  'washington',
#  'new',
#  'leader',
#  'new',
#  'school',
#  'new',
#  'vision',
#  'public',
#  'school',
#  'world',
#  'health',
#  'organ',
#  'opportun',
#  'intern',
#  'council',
#  'librari',
#  'inform',
#  'resourc',
#  'centr',
#  'advocaci',
#  'research',
#  'malaria',
#  'vaccin',
#  'initi',
#  'pan',
#  'american',
#  'health',
#  'educ',
#  'foundat',
#  'partnership',
#  'learn',
#  'probononet',
#  'St',
#  'mari',
#  'univers',
#  'san',
#  'antonio',
#  'univers',
#  'oklahoma',
#  'saddleback',
#  'memori',
#  'medic',
#  'center',
#  'convers',
#  'colleg',
#  'rowan',
#  'region',
#  'medic',
#  'center',
#  'minnesota',
#  'diversifi',
#  'industri',
#  'natur',
#  'conserv',
#  'minnesota',
#  'itasca',
#  'develop',
#  'corpor',
#  'american',
#  'red',
#  'cross',
#  'california',
#  'latino',
#  'medic',
#  'associ',
#  'tide',
#  'center',
#  'new',
#  'america',
#  'foundat',
#  'concordia',
#  'univers',
#  'california',
#  'millennium',
#  'park',
#  'muntu',
#  'danc',
#  'theater',
#  'chicago',
#  'american',
#  'red',
#  'cross',
#  'angel',
#  'network',
#  'american',
#  'red',
#  'cross',
#  'stanford',
#  'univers',
#  'irvin',
#  'ranch',
#  'land',
#  'reserv',
#  'trust',
#  'american',
#  'red',
#  'cross',
#  'american',
#  'red',
#  'cross',
#  'asia',
#  'societi',
#  'texa',
#  'swarthmor',
#  'colleg',
#  ...]

# %% [markdown]
# ##In-Class Assignment
#
# Generate a list of words using your dataset

# %% [markdown]
# ##3. Plotting a graph by counting the number of occurances of a word
#
# **Functions Used**
#
# 1. [nltk.FreqDist](http://www.nltk.org/api/nltk.html?highlight=freqdist)
# 2. [Plotting a FrqDist](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
fd=nltk.FreqDist(recipient_token_list)
fd.plot(10, cumulative=False, figure=plt.figure())

# %% [markdown]
# ##4. Removing insignifact words, appending stop_list

# %%
print(type(stop_words))
stop_words.append('university')
stop_words.append('foundation')

recipient_token_list_new=[]
for entry in df_main["Recipient"]:
    if str(entry)!='nan':
        recipient_token_list_new+=[stemmer.stem(s) for s in word_tokenize(entry) if s.lower() not in stop_words and s.isalpha()]

        
fd=nltk.FreqDist(recipient_token_list_new)
fd.plot(10, cumulative=False, figure=plt.figure())
# Out:
# <class 'list'>

# %% [markdown]
# ##In-Class Assignment
#
# Generate a frequency dist graph for your list of words

# %% [markdown]
# #Networkx
#
# Package Used:
# [netwrokx](https://networkx.github.io/documentation/stable/tutorial.html) is used to understand graphs and netwroks. Entities can be assigned as nodes, and two nodes can be linked to show a relation, this link is called edge.

# %%
import networkx as nx

data_edges = df_main[["Donor Name", "Recipient"]]

print(data_edges.head(10))

routers = []
routers.append(val for val in data_edges["Donor Name"].values.tolist() if val in data_edges["Recipient"].values.tolist())
print(routers)

for val in data_edges["Donor Name"].drop_duplicates().values:
  if val in data_edges["Recipient"].values:
    routers.append(val)
    
print(routers)
# Out:
#                           Donor Name  \
# 0                                 3M
# 1                                 3M
# 2               3M and 3M Foundation
# 3  A Gary Anderson Family Foundation
# 4                      A James Clark
# 5     A Theodore and Helen K Persson
# 6                              AFLAC
# 7                              AFLAC
# 8                              AFLAC
# 9                              AFLAC
#
#                                            Recipient
# 0                           Hurricane relief efforts
# 1                             Various relief efforts
# 2                                 American Red Cross
# 3                                 Chapman University
# 4                   University of Maryland - Adelphi
# 5                                 Colgate University
# 6                            Smithsonian Institution
# 7                                 American Red Cross
# 8  Smithsonian Institution - National Museum of A...
# 9           Martin Luther King, Jr National Memorial
# [<generator object <genexpr> at 0x7f0f29245eb8>]
# [<generator object <genexpr> at 0x7f0f29245eb8>, 'American Foundation', 'American Red Cross', 'Annenberg Foundation', 'Bernard Osher Foundation', 'Bill & Melinda Gates Foundation', 'Blanche and Julian Robertson Family Foundation', 'Charles K Blandin Foundation', 'Bush Foundation', 'California Community Foundation', 'California Endowment', 'California Institute for Regenerative Medicine', 'Carnegie Corporation of New York', 'Cleveland Clinic', 'Cleveland Foundation', 'Colorado Trust', 'Communities Foundation of Texas', 'Community Foundation of the Eastern Shore', 'Conrad N Hilton Foundation', 'Daniels Fund', 'Desert Healthcare District', 'Donald W Reynolds Foundation', 'Ellison Medical Foundation', 'Entertainment Industry Foundation', 'Erickson Foundation', 'Evjue Foundation', 'Florida Communities Trust', 'Florida Hospital', 'Ford Foundation', 'Freddie Mac Foundation', 'Give2Asia', 'Gordon and Betty Moore Foundation', 'Kessler Foundation', 'William and Flora Hewlett Foundation', 'Highmark Foundation', 'J A and Kathryn Albertson Foundation', 'James F and Marion L Miller Foundation', 'Kaiser Permanente', 'Kiwanis International Foundation', 'Kresge Foundation', 'Lance Armstrong Foundation', 'Lilly Endowment Inc', "Maddie's Fund", 'McKnight Foundation', 'Merck Childhood Asthma Network', 'Michael and Susan Dell Foundation', 'Muscular Dystrophy Association', 'National Science Foundation', 'Open Society Foundations', "Oprah's Angel Network", 'Pew Charitable Trusts', 'Pioneer Fund', 'Sallie Mae Fund', 'Skillman Foundation', 'Tides Foundation', 'W K Kellogg Foundation', 'Wachovia Foundation', 'Walton Family Foundation', 'William J Clinton Foundation', 'Philadelphia Foundation', 'Lutheran World Relief', 'New York Community Trust', 'World Wildlife Fund', 'Food for the Hungry', 'Nature Conservancy', 'Community Foundation for the National Capital Region', 'Ayco Charitable Foundation', 'Jewish Communal Fund', 'Schwab Charitable Fund', 'American Diabetes Association', 'American Israel Education Foundation', 'Jewish Community Federation of Cleveland', 'Vanguard Charitable Endowment Program', 'National Philanthropic Trust', 'Craig and Susan McCaw Foundation', 'Skoll Foundation', 'Alliance for Lupus Research', 'Winston-Salem Foundation', 'Baltimore Community Foundation', 'Jewish Federation of Metropolitan Chicago', 'Community Foundation for Greater Atlanta', 'Mayo Clinic', 'Community Foundation for Southeast Michigan', 'Greater Kansas City Community Foundation', 'Iris Foundation', 'William Penn Foundation', 'Silicon Valley Community Foundation', 'Community Foundation of Middle Tennessee', 'Nike Foundation', 'Edna McConnell Clark Foundation', 'Elizabeth A Sackler Foundation', 'NoVo Foundation', 'San Francisco Foundation', 'California Masonic Foundation', 'Community Foundation of Greater Chattanooga', 'Global Impact', 'Foundation for the Carolinas', 'Houston Food Bank', 'United Way of Greater Los Angeles', 'Susan Thompson Buffett Foundation', 'Mercy Corps', 'Jewish Federation of Greater Philadelphia', 'Covenant Foundation', "Huntington's Disease Society of America", 'Boston Foundation', 'Chicago Community Foundation', 'Chicago Community Trust', 'Robin Hood Foundation', "Lucile Packard Foundation for Children's Health", 'Moyer Foundation', 'San Diego Foundation', 'Greater Cincinnati Foundation', 'Iowa West Foundation', 'Rural Community Assistance Corporation', "Children's Health Fund", 'Community First Foundation', 'Columbus Foundation', 'Marin Community Foundation', 'Bank of America Charitable Gift Fund', 'Armenian General Benevolent Union', 'Dallas Foundation', 'Simmons Family Foundation', 'National Italian American Foundation', 'John C Lincoln Health Foundation', 'Spectrum Health Foundation', 'Extra Mile Education Foundation', 'Bessemer National Gift Fund', 'Oregon Community Foundation', 'Aspen Institute', 'Jackie Robinson Foundation', 'NewSchools Venture Fund', 'Amarillo Area Foundation', 'American Jewish World Service', 'Church World Service', ...

# %%
#g.nodes(data=True)[0:10]

#Add third type for common names: Router

G = nx.Graph()
G.add_nodes_from(data_edges["Donor Name"], node_type="donor")
G.add_nodes_from(data_edges["Recipient"], node_type="recipient")
G.add_edges_from(data_edges.values)

#Change the type later
# if node in nx.node in router: change the node_type

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'3M': {'node_type': 'donor'}, '3M and 3M Foundation': {'node_type': 'donor'}, 'A Gary Anderson Family Foundation': {'node_type': 'donor'}, 'A James Clark': {'node_type': 'donor'}, 'A Theodore and Helen K Persson': {'node_type': 'donor'}, 'AFLAC': {'node_type': 'donor'}, 'AOL Time Warner': {'node_type': 'donor'}, 'AT&T Foundation': {'node_type': 'donor'}, 'Aaron Jones': {'node_type': 'donor'}, 'Abbott Fund': {'node_type': 'donor'}, 'Abbott Laboratories': {'node_type': 'donor'}, 'Accenture': {'node_type': 'donor'}, 'Accenture Foundation': {'node_type': 'donor'}, 'Addie and Glenn E Ketner, Sr': {'node_type': 'donor'}, 'Adrienne Arsht': {'node_type': 'donor'}, 'Advanced Micro Devices': {'node_type': 'donor'}, 'Alan and Harriet Ginsburg Family Foundation': {'node_type': 'donor'}, 'Albert J and Jule Smith': {'node_type': 'donor'}, 'Albert L (Buddy) Luce, Jr': {'node_type': 'donor'}, 'Albert Willner': {'node_type': 'donor'}, 'Albert and Margaret Alkek Foundation': {'node_type': 'donor'}, "Albertson's": {'node_type': 'donor'}, "Alex's Lemonade Stand": {'node_type': 'donor'}, 'Alexander W and Renate Dreyfoos, Jr': {'node_type': 'donor'}, 'Alexis and Jim Pugh': {'node_type': 'donor'}, 'Alfred P Sloan Foundation': {'node_type': 'donor'}, 'Alfred Z Solomon': {'node_type': 'donor'}, 'Alice and William H Goodwin, Jr': {'node_type': 'donor'}, 'Alicia McEvoy': {'node_type': 'donor'}, 'Allan P Newell': {'node_type': 'donor'}, 'Allen and Joan Bildner': {'node_type': 'donor'}, 'Allene and Ben Porter': {'node_type': 'donor'}, 'Alltel Corporation': {'node_type': 'donor'}, 'Alon USA': {'node_type': 'donor'}, 'Alpaugh Family Foundation': {'node_type': 'donor'}, 'Althea Stroum': {'node_type': 'donor'}, 'Altria Group': {'node_type': 'donor'}, 'Alumni of the College of Law': {'node_type': 'donor'}, 'Amerada Hess Corporation': {'node_type': 'donor'}, 'AmeriQuest': {'node_type': 'donor'}, 'American Express': {'node_type': 'donor'}, 'American Foundation': {'node_type': 'recipient'}, 'American Red Cross': {'node_type': 'recipient'}, 'Amgen': {'node_type': 'donor'}, 'Amgen Foundation': {'node_type': 'donor'}, 'Amy Robbins': {'node_type': 'donor'}, 'Andrea and Charles Volpe': {'node_type': 'donor'}, 'Andy Grove': {'node_type': 'donor'}, 'Andrew W Mellon Foundation': {'node_type': 'donor'}, 'Andrew and Virginia Rudd': {'node_type': 'donor'}, 'Anheuser-Busch': {'node_type': 'donor'}, 'Ann Swindells': {'node_type': 'donor'}, 'Alfred and Ann Goldstein': {'node_type': 'donor'}, 'Anne C Twaddle': {'node_type': 'donor'}, 'Anne and Robert Bass': {'node_type': 'donor'}, 'Annenberg Foundation': {'node_type': 'recipient'}, 'Annette and Harold Simmons': {'node_type': 'donor'}, 'Annie E Casey Foundation': {'node_type': 'donor'}, 'Anonymous': {'node_type': 'donor'}, 'Anthony Welters': {'node_type': 'donor'}, 'Arcadia Foundation': {'node_type': 'donor'}, 'Archer Daniels Midland Company': {'node_type': 'donor'}, 'Arcus Foundation': {'node_type': 'donor'}, 'Argosy Foundation': {'node_type': 'donor'}, 'Arlene and Harold Schnitzer': {'node_type': 'donor'}, 'Arthur E Benning': {'node_type': 'donor'}, 'Arthur M Blank Family Foundation': {'node_type': 'donor'}, 'Arthur Zankel': {'node_type': 'donor'}, 'Arthur and Pat Modell': {'node_type': 'donor'}, 'Artie McFerrin': {'node_type': 'donor'}, 'Asco Foundation': {'node_type': 'donor'}, 'Ashley Turner': {'node_type': 'donor'}, 'AstraZeneca Pharmaceuticals': {'node_type': 'donor'}, 'Atlantic Philanthropies': {'node_type': 'donor'}, 'Aubrey McClendon': {'node_type': 'donor'}, 'Avenir Foundation': {'node_type': 'donor'}, 'B Thomas Golisano': {'node_type': 'donor'}, 'BAE Systems': {'node_type': 'donor'}, 'BASF': {'node_type': 'donor'}, 'BB&T Charitable Foundation': {'node_type': 'donor'}, 'BB&T Corporation': {'node_type': 'donor'}, 'BD': {'node_type': 'donor'}, "BJ's Restaurants": {'node_type': 'donor'}, 'BMW': {'node_type': 'donor'}, 'BP Foundation': {'node_type': 'donor'}, 'BP America': {'node_type': 'donor'}, 'Bank of Am ...

# %%
for val in routers:
  G.nodes[val]['node_type'] = "router"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-baf0831485a7> in <module>()
#       1 for val in routers:
# ----> 2   G.nodes[val]['node_type'] = "router"
#
# /usr/local/lib/python3.6/dist-packages/networkx/classes/reportviews.py in __getitem__(self, n)
#     176
#     177     def __getitem__(self, n):
# --> 178         return self._nodes[n]
#     179
#     180     # Set methods
#
# KeyError: <generator object <genexpr> at 0x7f0f29245eb8>

# %%
G.nodes["American Foundation"]
# Out:
# {'node_type': 'recipient'}

# %%
G.edges(data=True) #[0:20]
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
nx.write_graphml(G, "test_donations.graphml")
